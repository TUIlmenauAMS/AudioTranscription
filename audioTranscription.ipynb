# %% [markdown]
# <a href="https://colab.research.google.com/github/TUIlmenauAMS/AudioTranscription/blob/main/audioTranscription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Script to transcribe an audio file using txtai

# %%
#Modified from:
#https://colab.research.google.com/github/neuml/txtai/blob/master/examples/11_Transcribe_audio_to_text.ipynb#scrollTo=-K2YJJzsVtfq
#or
#https://neuml.github.io/txtai/pipeline/audio/transcription/
#Gerald Schuller, April 2022

#%capture

# !pip install txtai

# Get test data
#!wget -N https://github.com/neuml/txtai/releases/download/v3.5.0/tests.tar.gz
#!tar -xvzf tests.tar.gz
# Out:
# ...
#      |████████████████████████████████| 127 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 8.6 MB 27.4 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.8 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 43.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.8 MB/s
# ...
#      |████████████████████████████████| 77 kB 5.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from txtai.pipeline import Transcription

# Create transcription model for English:
#transcribe = Transcription("facebook/wav2vec2-large-960h")
transcribe = Transcription()
# Out:
# Downloading:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/159 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/163 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %% [markdown]
# Upload the audio file to transcribe in the left "Files" panel,
# then copy and paste its path on the space behind "filename":

# %%
from IPython.display import Audio, display
#upload the audio file to transcribe in the left panel,
#then copy and paste its path on the space behind "filename"
filename = '/content/test3.wav' #@param {'type': 'string'}
Text=transcribe(filename)
print(Text)
# Out:
# This is satist one to three four five six
